# %% [markdown]
# ## Building a model which translates English to French

# %%
import numpy as np
import pandas as pd
import os
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,LSTM,Dense

batch_size=64
epochs=100
latent_dim=256 # here latent dim represent hidden state or cell state
num_samples=10000

data_path='/content/fra.txt'

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
input_characters=sorted(list(input_characters))
target_characters=sorted(list(target_characters))

num_encoder_tokens=len(input_characters)
num_decoder_tokens=len(target_characters)

max_encoder_seq_length=max([len(txt) for txt in input_texts])
max_decoder_seq_length=max([len(txt) for txt in target_texts])

# %%
print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 93
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %%
input_token_index=dict(
    [(char,i) for i, char in enumerate(input_characters)])
target_token_index=dict(
[(char,i) for i, char in enumerate(target_characters)])

# %%
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %% [markdown]
# ## Defining the encoder and decoder

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 6s 21ms/step - loss: 1.2142 - accuracy: 0.7331 - val_loss: 1.0653 - val_accuracy: 0.7137
# Epoch 2/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.9385 - accuracy: 0.7497 - val_loss: 0.9705 - val_accuracy: 0.7251
# Epoch 3/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.8438 - accuracy: 0.7658 - val_loss: 0.8964 - val_accuracy: 0.7398
# Epoch 4/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.7483 - accuracy: 0.7902 - val_loss: 0.7795 - val_accuracy: 0.7727
# Epoch 5/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.6720 - accuracy: 0.8069 - val_loss: 0.7229 - val_accuracy: 0.7902
# Epoch 6/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.6301 - accuracy: 0.8168 - val_loss: 0.6845 - val_accuracy: 0.8011
# Epoch 7/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.6016 - accuracy: 0.8237 - val_loss: 0.6568 - val_accuracy: 0.8101
# Epoch 8/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.5794 - accuracy: 0.8295 - val_loss: 0.6444 - val_accuracy: 0.8098
# Epoch 9/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.5598 - accuracy: 0.8352 - val_loss: 0.6174 - val_accuracy: 0.8204
# Epoch 10/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5415 - accuracy: 0.8405 - val_loss: 0.5993 - val_accuracy: 0.8233
# Epoch 11/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.5251 - accuracy: 0.8455 - val_loss: 0.5806 - val_accuracy: 0.8324
# Epoch 12/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.5135 - accuracy: 0.8493 - val_loss: 0.8068 - val_accuracy: 0.7991
# Epoch 13/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4995 - accuracy: 0.8536 - val_loss: 0.5629 - val_accuracy: 0.8378
# Epoch 14/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4860 - accuracy: 0.8573 - val_loss: 0.5476 - val_accuracy: 0.8387
# Epoch 15/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4736 - accuracy: 0.8605 - val_loss: 0.5397 - val_accuracy: 0.8418
# Epoch 16/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4632 - accuracy: 0.8631 - val_loss: 0.5333 - val_accuracy: 0.8443
# Epoch 17/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4531 - accuracy: 0.8664 - val_loss: 0.5237 - val_accuracy: 0.8464
# Epoch 18/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4435 - accuracy: 0.8690 - val_loss: 0.5157 - val_accuracy: 0.8487
# Epoch 19/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4350 - accuracy: 0.8714 - val_loss: 0.5125 - val_accuracy: 0.8493
# Epoch 20/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.4269 - accuracy: 0.8737 - val_loss: 0.5039 - val_accuracy: 0.8521
# Epoch 21/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.4190 - accuracy: 0.8757 - val_loss: 0.4946 - val_accuracy: 0.8548
# Epoch 22/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4117 - accuracy: 0.8779 - val_loss: 0.4892 - val_accuracy: 0.8566
# Epoch 23/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4047 - accuracy: 0.8799 - val_loss: 0.4859 - val_accuracy: 0.8578
# Epoch 24/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3979 - accuracy: 0.8817 - val_loss: 0.4849 - val_accuracy: 0.8580
# Epoch 25/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3918 - accuracy: 0.8833 - val_loss: 0.4786 - val_accuracy: 0.8587
# Epoch 26/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3854 - accuracy: 0.8852 - val_loss: 0.4717 - val_accuracy: 0.8613
# Epoch 27/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3793 - accuracy: 0.8873 - val_loss: 0.4695 - val_accuracy: 0.8619
# Epoch 28/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3736 - accuracy: 0.8888 - val_loss: 0.4680 - val_accuracy: 0.8627
# Epoch 29/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3681 - accuracy: 0.8903 - val_loss: 0.4645 - val_accuracy: 0.8642
# Epoch 30/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3624 - accuracy: 0.8919 - val_loss: 0.4593 - val_accuracy: 0.8642
# Epoch 31/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3572 - accuracy: 0.8935 - val_loss: 0.4617 - val_accuracy: 0.8641
# Epoch 32/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3519 - accuracy: 0.8949 - val_loss: 0.4533 - val_accuracy: 0.8666
# Epoch 33/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3469 - accuracy: 0.8964 - val_loss: 0.4522 - val_accuracy: 0.8672
# Epoch 34/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3426 - accuracy: 0.8981 - val_loss: 0.4577 - val_accuracy: 0.8653
# Epoch 35/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3373 - accuracy: 0.8994 - val_loss: 0.4503 - val_accuracy: 0.8674
# Epoch 36/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3326 - accuracy: 0.9007 - val_loss: 0.4493 - val_accuracy: 0.8688
# Epoch 37/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3282 - accuracy: 0.9020 - val_loss: 0.4501 - val_accuracy: 0.8685
# Epoch 38/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3240 - accuracy: 0.9033 - val_loss: 0.4468 - val_accuracy: 0.8697
# Epoch 39/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3194 - accuracy: 0.9046 - val_loss: 0.4425 - val_accuracy: 0.8706
# Epoch 40/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3153 - accuracy: 0.9058 - val_loss: 0.4419 - val_accuracy: 0.8711
# Epoch 41/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3110 - accuracy: 0.9071 - val_loss: 0.4439 - val_accuracy: 0.8702
# Epoch 42/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3068 - accuracy: 0.9083 - val_loss: 0.4389 - val_accuracy: 0.8722
# Epoch 43/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3028 - accuracy: 0.9097 - val_loss: 0.4397 - val_accuracy: 0.8721
# Epoch 44/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2988 - accuracy: 0.9105 - val_loss: 0.4449 - val_accuracy: 0.8719
# Epoch 45/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2947 - accuracy: 0.9122 - val_loss: 0.4427 - val_accuracy: 0.8721
# Epoch 46/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2908 - accuracy: 0.9128 - val_loss: 0.4401 - val_accuracy: 0.8730
# Epoch 47/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2871 - accuracy: 0.9142 - val_loss: 0.4397 - val_accuracy: 0.8731
# Epoch 48/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2829 - accuracy: 0.9155 - val_loss: 0.4385 - val_accuracy: 0.8740
# Epoch 49/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2798 - accuracy: 0.9163 - val_loss: 0.4378 - val_accuracy: 0.8739
# Epoch 50/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2761 - accuracy: 0.9173 - val_loss: 0.4408 - val_accuracy: 0.8739
# Epoch 51/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2721 - accuracy: 0.9185 - val_loss: 0.4431 - val_accuracy: 0.8740
# Epoch 52/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2685 - accuracy: 0.9196 - val_loss: 0.4398 - val_accuracy: 0.8751
# Epoch 53/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2649 - accuracy: 0.9205 - val_loss: 0.4385 - val_accuracy: 0.8754
# Epoch 54/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2618 - accuracy: 0.9215 - val_loss: 0.4398 - val_accuracy: 0.8747
# Epoch 55/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2584 - accuracy: 0.9225 - val_loss: 0.4367 - val_accuracy: 0.8762
# Epoch 56/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2546 - accuracy: 0.9238 - val_loss: 0.4442 - val_accuracy: 0.8747
# Epoch 57/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2512 - accuracy: 0.9245 - val_loss: 0.4434 - val_accuracy: 0.8746
# Epoch 58/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2485 - accuracy: 0.9256 - val_loss: 0.4483 - val_accuracy: 0.8744
# Epoch 59/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2447 - accuracy: 0.9264 - val_loss: 0.4452 - val_accuracy: 0.8755
# Epoch 60/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2413 - accuracy: 0.9277 - val_loss: 0.4443 - val_accuracy: 0.8756
# Epoch 61/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2386 - accuracy: 0.9286 - val_loss: 0.4432 - val_accuracy: 0.8774
# Epoch 62/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2352 - accuracy: 0.9294 - val_loss: 0.4440 - val_accuracy: 0.8768
# Epoch 63/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2314 - accuracy: 0.9306 - val_loss: 0.4475 - val_accuracy: 0.8760
# Epoch 64/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2287 - accuracy: 0.9312 - val_loss: 0.4464 - val_accuracy: 0.8769
# Epoch 65/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2259 - accuracy: 0.9320 - val_loss: 0.4461 - val_accuracy: 0.8766
# Epoch 66/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2230 - accuracy: 0.9329 - val_loss: 0.4488 - val_accuracy: 0.8769
# Epoch 67/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2201 - accuracy: 0.9337 - val_loss: 0.4503 - val_accuracy: 0.8771
# Epoch 68/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2173 - accuracy: 0.9346 - val_loss: 0.4562 - val_accuracy: 0.8770
# Epoch 69/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2140 - accuracy: 0.9358 - val_loss: 0.4518 - val_accuracy: 0.8764
# Epoch 70/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2111 - accuracy: 0.9366 - val_loss: 0.4555 - val_accuracy: 0.8764
# Epoch 71/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2088 - accuracy: 0.9372 - val_loss: 0.4577 - val_accuracy: 0.8766
# Epoch 72/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2060 - accuracy: 0.9382 - val_loss: 0.4594 - val_accuracy: 0.8763
# Epoch 73/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2032 - accuracy: 0.9392 - val_loss: 0.4653 - val_accuracy: 0.8762
# Epoch 74/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2004 - accuracy: 0.9396 - val_loss: 0.4623 - val_accuracy: 0.8762
# Epoch 75/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1977 - accuracy: 0.9406 - val_loss: 0.4633 - val_accuracy: 0.8772
# Epoch 76/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1950 - accuracy: 0.9413 - val_loss: 0.4677 - val_accuracy: 0.8763
# Epoch 77/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1924 - accuracy: 0.9421 - val_loss: 0.4700 - val_accuracy: 0.8766
# Epoch 78/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1904 - accuracy: 0.9428 - val_loss: 0.4744 - val_accuracy: 0.8756
# Epoch 79/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1875 - accuracy: 0.9439 - val_loss: 0.4716 - val_accuracy: 0.8765
# Epoch 80/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1847 - accuracy: 0.9444 - val_loss: 0.4751 - val_accuracy: 0.8766
# Epoch 81/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1831 - accuracy: 0.9448 - val_loss: 0.4731 - val_accuracy: 0.8771
# Epoch 82/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1800 - accuracy: 0.9459 - val_loss: 0.4739 - val_accuracy: 0.8778
# Epoch 83/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1780 - accuracy: 0.9464 - val_loss: 0.4804 - val_accuracy: 0.8770
# Epoch 84/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1758 - accuracy: 0.9472 - val_loss: 0.4825 - val_accuracy: 0.8769
# Epoch 85/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1729 - accuracy: 0.9480 - val_loss: 0.4827 - val_accuracy: 0.8773
# Epoch 86/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1709 - accuracy: 0.9485 - val_loss: 0.4835 - val_accuracy: 0.8765
# Epoch 87/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1689 - accuracy: 0.9490 - val_loss: 0.4915 - val_accuracy: 0.8768
# Epoch 88/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1667 - accuracy: 0.9498 - val_loss: 0.4862 - val_accuracy: 0.8768
# Epoch 89/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1643 - accuracy: 0.9505 - val_loss: 0.5019 - val_accuracy: 0.8760
# Epoch 90/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1622 - accuracy: 0.9512 - val_loss: 0.4919 - val_accuracy: 0.8766
# Epoch 91/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1603 - accuracy: 0.9514 - val_loss: 0.4953 - val_accuracy: 0.8767
# Epoch 92/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1578 - accuracy: 0.9523 - val_loss: 0.4984 - val_accuracy: 0.8763
# Epoch 93/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1558 - accuracy: 0.9527 - val_loss: 0.5026 - val_accuracy: 0.8764
# Epoch 94/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1541 - accuracy: 0.9532 - val_loss: 0.5076 - val_accuracy: 0.8754
# Epoch 95/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1520 - accuracy: 0.9540 - val_loss: 0.5053 - val_accuracy: 0.8769
# Epoch 96/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1502 - accuracy: 0.9547 - val_loss: 0.5132 - val_accuracy: 0.8751
# Epoch 97/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1481 - accuracy: 0.9553 - val_loss: 0.5127 - val_accuracy: 0.8761
# Epoch 98/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1467 - accuracy: 0.9553 - val_loss: 0.5119 - val_accuracy: 0.8767
# Epoch 99/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1444 - accuracy: 0.9560 - val_loss: 0.5176 - val_accuracy: 0.8766
# Epoch 100/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1425 - accuracy: 0.9567 - val_loss: 0.5174 - val_accuracy: 0.8763

# %%
# model.save('eng2french.h5')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 70)]           0         []
#
#  input_2 (InputLayer)        [(None, None, 93)]           0         []
#
#  lstm (LSTM)                 [(None, 256),                334848    ['input_1[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  lstm_1 (LSTM)               [(None, None, 256),          358400    ['input_2[0][0]',
#                               (None, 256),                           'lstm[0][1]',
#                               (None, 256)]                           'lstm[0][2]']
#
#  dense (Dense)               (None, None, 93)             23901     ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 717149 (2.74 MB)
# Trainable params: 717149 (2.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
from nltk.translate.bleu_score import sentence_bleu
for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)

    print('BLEU score -> {}'.format(sentence_bleu(input_texts[seq_index],decoded_sentence)))
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Go.
# Decoded sentence: Cassez-vous.
#
# BLEU score -> 1.1409851298103347e-231
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Go.
# Decoded sentence: Cassez-vous.
#
# BLEU score -> 1.1409851298103347e-231
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Go.
# Decoded sentence: Cassez-vous.
#
# BLEU score -> 1.1409851298103347e-231
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# -
# Input sentence: Go.
# Decoded sentence: Cassez-vous.
#
# BLEU score -> 1.1409851298103347e-231
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# BLEU score -> 1.1200407237786664e-231
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# BLEU score -> 1.1200407237786664e-231
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# BLEU score -> 1.2882297539194154e-231
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# BLEU score -> 1.2882297539194154e-231
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# BLEU score -> 1.2882297539194154e-231
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# BLEU score -> 1.2882297539194154e-231
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# BLEU score -> 1.2882297539194154e-231
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# BLEU score -> 1.2882297539194154e-231
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# BLEU score -> 1.2882297539194154e-231
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Run!
# Decoded sentence: Fuyez !
#
# BLEU score -> 1.2882297539194154e-231
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyons !
#
# BLEU score -> 1.2508498911928379e-231
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyons !
#
# BLEU score -> 1.2508498911928379e-231
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyons !
#
# BLEU score -> 1.2508498911928379e-231
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyons !
#
# BLEU score -> 1.2508498911928379e-231
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyons !
#
# BLEU score -> 1.2508498911928379e-231
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Run.
# Decoded sentence: Fuyons !
#
# BLEU score -> 1.2508498911928379e-231
